# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# load data
df = pd.read_csv('Diabetes Dataset.csv')

# %%
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
#correlration matrix
plt.figure(figsize=(5, 5))
sns.heatmap(df.corr(), annot=True, cmap='coolwarm' , fmt="1.1f")
plt.title('Correlation Matrix')
# Out:
# Text(0.5, 1.0, 'Correlation Matrix')

# %%
# scatter plot
plt.figure(figsize=(5, 5))
sns.scatterplot( data=df , x='BloodPressure', y='BMI' )
plt.title('Scatter Plot')
plt.xlabel('BloodPressure')
plt.ylabel('BMI')
# Out:
# Text(0, 0.5, 'BMI')

# %%
# Distribution plot 
fd = ['Pregnancies', 'SkinThickness', 'Age']
for i in fd:
    plt.figure(figsize=(5, 5))
    sns.histplot(df[i], kde=True, bins=20, color='blue')
    plt.ylabel("Frequency")
    plt.title(f'Distribution Plot: {i}')

# %%
# Pie chart
outcome_ct = df['Outcome'].value_counts()
plt.figure(figsize=(5, 5))
outcome_ct.plot.pie(autopct='%1.1f%%', startangle=90, colors=['skyblue', 'red'], labels=['No Diabetes', 'Diabetes'])
plt.title('Pie Chart')
plt.ylabel('')
# Out:
# Text(0, 0.5, '')

# %%
# boxplot
fbox = ['SkinThickness', 'DiabetesPedigreeFunction', 'BloodPressure']
for i in fbox:
    plt.figure(figsize=(5, 5))
    sns.boxplot(x=df[i])
    plt.title(f'Boxplot: {i}')

# %%
# mode_mean_median
print("Central Tendency:")
for i in df.columns[:9]: 
    print(f"Feature: {i}")
    print(f"  Mean: {df[i].mean()}")
    print(f"  Median: {df[i].median()}")
    print(f"  Mode: {df[i].mode()[0]}")
# Out:
# Central Tendency:
# Feature: Pregnancies
#   Mean: 3.8450520833333335
#   Median: 3.0
#   Mode: 1
# Feature: Glucose
#   Mean: 120.89453125
#   Median: 117.0
#   Mode: 99
# Feature: BloodPressure
#   Mean: 69.10546875
#   Median: 72.0
#   Mode: 70
# Feature: SkinThickness
#   Mean: 20.536458333333332
#   Median: 23.0
#   Mode: 0
# Feature: Insulin
#   Mean: 79.79947916666667
#   Median: 30.5
#   Mode: 0
# Feature: BMI
#   Mean: 31.992578124999998
#   Median: 32.0
#   Mode: 32.0
# Feature: DiabetesPedigreeFunction
#   Mean: 0.47187630208333325
#   Median: 0.3725
#   Mode: 0.254
# Feature: Age
#   Mean: 33.240885416666664
#   Median: 29.0
#   Mode: 22
# Feature: Outcome
#   Mean: 0.3489583333333333
#   Median: 0.0
#   Mode: 0

# %%
# Standard and min_max
print("Dispersion:")
for col in df.columns[:9]: 
    print(f"Feature: {col}")
    print(f"  Standard Deviation: {df[col].std()}")
    print(f"  Variance: {df[col].var()}")
    print(f"  Min: {df[col].min()}")
    print(f"  Max: {df[col].max()}")
# Out:
# Dispersion:
# Feature: Pregnancies
#   Standard Deviation: 3.3695780626988694
#   Variance: 11.354056320621465
#   Min: 0
#   Max: 17
# Feature: Glucose
#   Standard Deviation: 31.97261819513622
#   Variance: 1022.2483142519557
#   Min: 0
#   Max: 199
# Feature: BloodPressure
#   Standard Deviation: 19.355807170644777
#   Variance: 374.6472712271838
#   Min: 0
#   Max: 122
# Feature: SkinThickness
#   Standard Deviation: 15.952217567727637
#   Variance: 254.47324532811822
#   Min: 0
#   Max: 99
# Feature: Insulin
#   Standard Deviation: 115.24400235133817
#   Variance: 13281.180077955238
#   Min: 0
#   Max: 846
# Feature: BMI
#   Standard Deviation: 7.884160320375446
#   Variance: 62.15998395738266
#   Min: 0.0
#   Max: 67.1
# Feature: DiabetesPedigreeFunction
#   Standard Deviation: 0.3313285950127749
#   Variance: 0.1097786378731394
#   Min: 0.078
#   Max: 2.42
# Feature: Age
#   Standard Deviation: 11.760231540678685
#   Variance: 138.30304589037377
#   Min: 21
#   Max: 81
# ...
